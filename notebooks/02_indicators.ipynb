# %% [markdown]
# # 02 - Indicadores Derivados

# %%
import sys
sys.path.insert(0, '..')
from src.data_loader import load_cities, save_processed
from src.indicators import add_derived_indicators
from src.utils import top_cities

# %%
import pandas as pd
from pathlib import Path
from src.indicators import add_derived_indicators
from src.data_loader import save_processed
from src.utils import top_cities

df = pd.read_csv('../data/processed/cities.csv')
df = add_derived_indicators(df)
save_processed(df, 'cities_processed.csv')
top_cities(df, n=10)
# Out:
# Guardado: c:\Users\Damián\Desktop\RelocationDevs\notebooks\..\data\processed\cities_processed.csv
#          city_name        country    region  average_salary  average_rent  \
# 0      Houston, TX  United States  Americas           52107          1397
# 1       Dallas, TX  United States  Americas           52107          1615
# 2    Ann Arbor, MI  United States  Americas           52107          1545
# 3       Austin, TX  United States  Americas           52107          1857
# 4     San Jose, CA  United States  Americas           52107          2650
# 5      Fremont, CA  United States  Americas           52107          2413
# 6  Jersey City, NJ  United States  Americas           52107          2029
# 7  Santa Clara, CA  United States  Americas           52107          2911
# 8     Columbus, OH  United States  Americas           52107          1192
# 9      Seattle, WA  United States  Americas           52107          2120
#
#    tax_rate  cost_of_living_index  purchasing_power_index  \
# 0      43.6                 63.94                  172.98
# 1      43.6                 67.85                  170.66
# 2      43.6                 70.28                  159.99
# 3      43.6                 66.50                  158.21
# 4      43.6                 73.71                  157.39
# 5      43.6                 74.12                  157.35
# 6      43.6                 80.79                  155.89
# 7      43.6                 89.41                  155.41
# 8      43.6                 69.70                  151.29
# 9      43.6                 88.52                  145.39
#
#    quality_of_life_index  job_market_score  net_salary  purchasing_power  \
# 0                  126.3             100.0   29388.348        459.623835
# 1                  125.0              98.6   29388.348        433.137038
# 2                  118.6              92.4   29388.348        418.160899
# 3                  117.5              91.4   29388.348        441.930045
# 4                  117.0              90.9   29388.348        398.702320
# 5                  117.0              90.9   29388.348        396.496870
# 6                  116.1              90.0   29388.348        363.762198
# 7                  115.8              89.7   29388.348        328.691958
# 8                  113.3              87.3   29388.348        421.640574
# 9                  109.8              83.9   29388.348        331.996701
#
#    annual_savings  relocation_score
# 0       8816.5044            119.75
# 1       8816.5044            118.38
# 2       8816.5044            112.03
# 3       8816.5044            110.97
# 4       8816.5044            110.47
# 5       8816.5044            110.46
# 6       8816.5044            109.57
# 7       8816.5044            109.28
# 8       8816.5044            106.82
# 9       8816.5044            103.32
